# %%
with open('pwsh.envs.txt', 'r') as f:
    pwsh_lines = f.readlines()
    # for line in f:
        # print(line.strip())
        # print(f'export {line.strip()}')

with open('bash.envs.txt', 'r') as bf:
    bash_envs = bf.readlines()

# %%
for i, linea_pwsh in enumerate(pwsh_lines):
    # print(i, linea_pwsh)
    if linea_pwsh in bash_envs:
        print(f'export {linea_pwsh.strip()}')
